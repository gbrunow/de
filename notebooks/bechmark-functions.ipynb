# %% [markdown]
# # Benchark Functions

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
import sys
import os
sys.path.insert(0, os.path.join(os.getcwd(), '..', 'src'))
from benchmark.simple import rosenbrock, rastrigin, shubert

# %% [markdown]
# ## Rosenbrock

# %% [markdown]
# $$f(x_1 \cdots x_n) = \sum_{i=1}^{n-1} [b(x_{i+1} - x_i^2)^2 + (a-x_i)^2]$$ where $a = 1$ and $b = 100$

# %%
X = np.arange(-2, 2, 0.1)
Y = np.arange(-2, 2, 0.1)
X, Y = np.meshgrid(X, Y)
Xs = np.array([X, Y])
Z = rosenbrock(Xs)

fig = plt.figure()

ax = fig.gca(projection='3d')
ax.view_init(30, 130)

surf = ax.plot_surface(
    X, Y, Z, cmap=cm.plasma,
    linewidth=0, antialiased=False
)

plt.show()

# %% [markdown]
# ## Rastrigin

# %% [markdown]
# $$f(x_1 \cdots x_n)=An + \sum_{i=1}^{n}(x_i^2 - Acos(2\pi x_i))$$ where $A = 10$

# %%
X = np.arange(-5, 5, 0.1)
Y = np.arange(-5, 5, 0.1)
X, Y = np.meshgrid(X, Y)
Xs = np.array([X, Y])
Z = rastrigin(Xs)

fig2 = plt.figure()

ax = fig2.gca(projection='3d')
ax.view_init(45, 130)

surf = ax.plot_surface(
    X, Y, Z, cmap=cm.magma,
    linewidth=0, antialiased=False
)

plt.show()

# %% [markdown]
# ## Shubert

# %%
data = np.mgrid[-5:5:0.1,-5:5:0.1]
x = data[0].reshape(-1)
y = data[1].reshape(-1)
z = shubert(x,y)

fig3 = plt.figure()

ax = fig3.gca(projection='3d')
ax.view_init(65, 130)

surf = ax.plot_trisurf(
    x, y, z, cmap=cm.magma,
    linewidth=0, antialiased=False
)

plt.show()
